# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fd = pd.read_csv("D:/fertility.csv")

# %%
fd.head()
# Out:
#    Season  Age  Childish diseases  Accident or serious trauma  \
# 0  spring   30                  0                           1
# 1  spring   35                  1                           0
# 2  spring   27                  1                           0
# 3  spring   32                  0                           1
# 4  spring   30                  1                           1
#
#    Surgical intervention High fevers in the last year  \
# 0                      1       more than 3 months ago
# 1                      1       more than 3 months ago
# 2                      0       more than 3 months ago
# 3                      1       more than 3 months ago
# 4                      0       more than 3 months ago
#
#   Frequency of alcohol consumption  Smoking habit  \
# 0                      once a week              2
# 1                      once a week              1
# 2             hardly ever or never              3
# 3             hardly ever or never              3
# ...

# %%
fd.tail()
# Out:
#     Season  Age  Childish diseases  Accident or serious trauma  \
# 95  winter   30                  1                           0
# 96  winter   29                  1                           0
# 97  winter   30                  1                           1
# 98  winter   30                  1                           0
# 99  winter   30                  0                           1
#
#     Surgical intervention High fevers in the last year  \
# 95                      0       more than 3 months ago
# 96                      0       more than 3 months ago
# 97                      1       more than 3 months ago
# 98                      1       more than 3 months ago
# 99                      1       more than 3 months ago
#
#    Frequency of alcohol consumption  Smoking habit  \
# 95             hardly ever or never              3
# 96                      once a week              2
# 97             hardly ever or never              3
# ...

# %%
fd.shape
# Out:
# (100, 10)

# %%
fd.info
# Out:
# <bound method DataFrame.info of     Season  Age  Childish diseases  Accident or serious trauma  \
# 0   spring   30                  0                           1
# 1   spring   35                  1                           0
# 2   spring   27                  1                           0
# 3   spring   32                  0                           1
# 4   spring   30                  1                           1
# ..     ...  ...                ...                         ...
# 95  winter   30                  1                           0
# 96  winter   29                  1                           0
# 97  winter   30                  1                           1
# 98  winter   30                  1                           0
# 99  winter   30                  0                           1
#
#     Surgical intervention High fevers in the last year  \
# 0                       1       more than 3 months ago
# 1                       1       more than 3 months ago
# ...

# %%
fd.describe()
# Out:
#               Age  Childish diseases  Accident or serious trauma  \
# count  100.000000         100.000000                  100.000000
# mean    30.110000           0.870000                    0.440000
# std      2.246861           0.337998                    0.498888
# min     27.000000           0.000000                    0.000000
# 25%     28.000000           1.000000                    0.000000
# 50%     30.000000           1.000000                    0.000000
# 75%     32.000000           1.000000                    1.000000
# max     36.000000           1.000000                    1.000000
#
#        Surgical intervention  Smoking habit  \
# count             100.000000     100.000000
# mean                0.510000       2.350000
# std                 0.502418       0.808728
# min                 0.000000       1.000000
# 25%                 0.000000       2.000000
# 50%                 1.000000       3.000000
# 75%                 1.000000       3.000000
# ...

# %%
fd.columns
# Out:
# Index(['Season', 'Age', 'Childish diseases', 'Accident or serious trauma',
#        'Surgical intervention', 'High fevers in the last year',
#        'Frequency of alcohol consumption', 'Smoking habit',
#        'Number of hours spent sitting per day', 'Diagnosis'],
#       dtype='object')

# %% [markdown]
# # Sort Data

# %%
sort_age = fd["Age"]

# %%
sort_age.sort_values(ascending = True)
# Out:
# 2     27
# 66    27
# 67    27
# 68    27
# 73    27
#       ..
# 80    35
# 1     35
# 14    35
# 79    36
# 7     36
# Name: Age, Length: 100, dtype: int64

# %%
sort_age.max()
# Out:
# 36

# %%
sort_age.min()
# Out:
# 27

# %% [markdown]
# # Line Plot

# %%
plt.figure(figsize = (16,8))
plt.plot(sort_age)
plt.title("Age")
plt.xlabel("No. of Patient")
plt.ylabel("Age")
plt.show()

# %%
sort_age.describe
# Out:
# <bound method NDFrame.describe of 0     30
# 1     35
# 2     27
# 3     32
# 4     30
#       ..
# 95    30
# 96    29
# 97    30
# 98    30
# 99    30
# Name: Age, Length: 100, dtype: int64>

# %%
se = fd.sort_values("Season")
se
# Out:
#     Season  Age  Childish diseases  Accident or serious trauma  \
# 26    fall   30                  1                           0
# 20    fall   30                  0                           0
# 21    fall   32                  1                           0
# 22    fall   30                  1                           1
# 23    fall   30                  1                           0
# ..     ...  ...                ...                         ...
# 74  winter   28                  1                           0
# 75  winter   32                  1                           0
# 77  winter   31                  1                           1
# 42  winter   28                  1                           0
# 99  winter   30                  0                           1
#
#     Surgical intervention High fevers in the last year  \
# 26                      1       more than 3 months ago
# 20                      1       more than 3 months ago
# ...

# %%
se = fd["Number of hours spent sitting per day"]

# %%
plt.figure(figsize = (16,8))
plt.bar(sort_age, se, color = "m")
plt.xlabel("Age")
plt.ylabel("Sleep")
plt.show()
